# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %%
from algorithm import BranchAndBound

problem = {
    "variables": ["x1", "x2"],
    "objective": {"x1": 7, "x2": 5},
    "constraints": [
        ({"x1": 2, "x2": 1}, "<=", 5),
        ({"x1": 1, "x2": 2}, "<=", 6),
    ]
}

bnb = BranchAndBound(problem)
result = bnb.solve()

print("RESULT:")
print(result)
# Out:
# Node 0: LP solution = {'x1': 1.3333333333333333, 'x2': 2.3333333333333335}, objective = 21.0
# Branching on x2 = 2.333
#   Left: x2 <= 2
#   Right: x2 >= 3
# Node 0: LP solution = {'x1': 1.5, 'x2': 2.0}, objective = 20.5
# Branching on x1 = 1.500
#   Left: x1 <= 1
#   Right: x1 >= 2
# Node 2: LP solution = {'x1': 1.0, 'x2': 2.0}, objective = 17.0
# New incumbent: {'x1': 1, 'x2': 2}, value: 17.0
# Node 3: LP solution = {'x1': 2.0, 'x2': 1.0}, objective = 19.0
# New incumbent: {'x1': 2, 'x2': 1}, value: 19.0
# Node 1: LP solution = {'x1': 1.3333333333333333, 'x2': 2.3333333333333335}, objective = 21.0
# Branching on x2 = 2.333
#   Left: x2 <= 2
#   Right: x2 >= 3
# Node 4: LP solution = {'x1': 1.5, 'x2': 2.0}, objective = 20.5
# Branching on x1 = 1.500
#   Left: x1 <= 1
#   Right: x1 >= 2
# Node 6: LP solution = {'x1': 1.0, 'x2': 2.0}, objective = 17.0
# Node 7: LP solution = {'x1': 2.0, 'x2': 1.0}, objective = 19.0
# ...
